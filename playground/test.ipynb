# %%
from autovc.voice_converter import VoiceConverter
import torch

# %%
torch.load('../models/SpeakerEncoder/SpeakerEncoder.pt')
# Out:
# {'step': 1564501,
#  'model_state': OrderedDict([('similarity_weight', tensor([70.8929])),
#               ('similarity_bias', tensor([-4.1807])),
#               ('lstm.weight_ih_l0',
#                tensor([[ 0.0429, -0.3057,  0.0919,  ..., -0.2085, -0.1205, -0.1414],
#                        [ 0.0597,  0.0638,  0.2041,  ..., -1.3857, -2.1012, -0.6834],
#                        [ 0.1323, -0.9001, -1.6876,  ..., -0.6913, -1.7947, -1.4535],
#                        ...,
#                        [ 0.0260,  0.0371,  0.0684,  ...,  0.2883,  0.1728, -0.1809],
#                        [ 0.2276,  0.0583,  0.0553,  ..., -1.2925, -0.5400, -0.5357],
#                        [-0.0599, -0.0666, -0.0342,  ..., -0.0846, -0.1720, -0.5394]],
#                       device='cuda:0')),
#               ('lstm.weight_hh_l0',
#                tensor([[-0.3233, -0.5943,  0.4106,  ..., -0.1813,  0.3072,  0.6071],
#                        [-0.4110,  0.4495,  0.1779,  ...,  0.2767,  0.2444,  0.3096],
# ...

# %%
VoiceConverter(
    auto_encoder='../models/AutoVC/AutoVC_SMK.pt', 
    speaker_encoder='../models/SpeakerEncoder/SpeakerEncoder.pt',
    vocoder='../models/WaveRNN/WaveRNN_Pretrained.pyt'
)
# Out:
# Loaded auto encoder "../models/AutoVC/AutoVC_SMK.pt" trained to step 13801
# Loaded speaker encoder "../models/SpeakerEncoder/SpeakerEncoder.pt" trained to step 1564501
# Loaded vocoder "../models/WaveRNN/WaveRNN_Pretrained.pyt"

# %%
import torch
torch.cuda.get_device_name()
# Out:
# 'NVIDIA GeForce GTX 1650 Ti'
